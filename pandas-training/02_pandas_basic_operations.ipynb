# %% [markdown]
# # Pandas - Basic Operations

# %% [markdown]
# ### DataFrame - deep copy

# %%
import pandas as pd

# %%
dict = {'A' : [1 ,2, 3, 4, 5], 'B': ['a', 'b', 'c', 'd', 'e'], 'NUM': [0, 0, 0, 0, 0 ]}
df1 = pd.DataFrame(dict)
df1
# Out:
#    A  B  NUM
# 0  1  a    0
# 1  2  b    0
# 2  3  c    0
# 3  4  d    0
# 4  5  e    0

# %%
df2 = df1.copy() # deep copy is the default option
df2
# Out:
#    A  B  NUM
# 0  1  a    0
# 1  2  b    0
# 2  3  c    0
# 3  4  d    0
# 4  5  e    0

# %%
df2.drop(0, inplace=True)

# %%
df2
# Out:
#    A  B  NUM
# 1  2  b    0
# 2  3  c    0
# 3  4  d    0
# 4  5  e    0

# %%
df1
# Out:
#    A  B  NUM
# 0  1  a    0
# 1  2  b    0
# 2  3  c    0
# 3  4  d    0
# 4  5  e    0

# %% [markdown]
# ### DataFrame - shallow copy

# %%
df3 = df1.copy(deep = False) # 
df3
# Out:
#    A  B  NUM
# 0  1  a    0
# 1  2  b    0
# 2  3  c    0
# 3  4  d    0
# 4  5  e    0

# %% [markdown]
# ### Get column list

# %%
df3
# Out:
#    A  B  NUM
# 0  1  a    0
# 1  2  b    0
# 2  3  c    0
# 3  4  d    0
# 4  5  e    0

# %%
df3.columns
# Out:
# Index(['A', 'B', 'NUM'], dtype='object')

# %%
df3.columns.to_list()
# Out:
# ['A', 'B', 'NUM']

# %% [markdown]
# ### Add a new column

# %%
dictx = {'A' : [1 ,1, 3, 4, 5], 'B': ['a', 'a', 'c', 'd', 'e'], 'NUM': [0, 0, 0, 0, 0 ]}
dfx = pd.DataFrame(dictx)
dfx
# Out:
#    A  B  NUM
# 0  1  a    0
# 1  1  a    0
# 2  3  c    0
# 3  4  d    0
# 4  5  e    0

# %% [markdown]
# #### Add new column at the end

# %%
# with the same value in each row
dfx['X'] = 'X'
dfx
# Out:
#    A  B  NUM  X  ID
# 0  1  a    0  X   0
# 1  1  a    0  X   1
# 2  3  c    0  X   2
# 3  4  d    0  X   3
# 4  5  e    0  X   4

# %% [markdown]
# #### Add new column at a specific position

# %%
dfx.insert(2, 'NEW_X', [10, 20, 30, 40, 50])
dfx
# Out:
#    A  B  NEW_X  NUM  X  ID
# 0  1  a     10    0  X   0
# 1  1  a     20    0  X   1
# 2  3  c     30    0  X   2
# 3  4  d     40    0  X   3
# 4  5  e     50    0  X   4

# %%
# with an incremental values in each row
dfx['ID'] = range(len(dfx)) 
dfx
# Out:
#    A  B  NUM  X  ID
# 0  1  a    0  X   0
# 1  1  a    0  X   1
# 2  3  c    0  X   2
# 3  4  d    0  X   3
# 4  5  e    0  X   4

# %% [markdown]
# #### Using assign method

# %%
dfxr1 = dfx.assign(row_number=range(1,len(dfx)+1)) # the new column will be called 'row_number'
dfxr1
# Out:
#    A  B  NUM  row_number
# 0  1  a    0           1
# 1  1  a    0           2
# 2  3  c    0           3
# 3  4  d    0           4
# 4  5  e    0           5

# %%
dictx = {'A' : [1 ,1, 3, 4, 5], 'B': ['a', 'a', 'c', 'd', 'e'], 'NUM': [0, 0, 0, 0, 0 ]}
dfx = pd.DataFrame(dictx)
dfx
# Out:
#    A  B  NUM
# 0  1  a    0
# 1  1  a    0
# 2  3  c    0
# 3  4  d    0
# 4  5  e    0

# %%
dfx_grupped = dfx.groupby(['A', 'B', 'NUM']).size().reset_index() #.rename(columns={0:'count'})
dfx_grupped
# Out:
#    A  B  NUM  0
# 0  1  a    0  2
# 1  3  c    0  1
# 2  4  d    0  1
# 3  5  e    0  1

# %% [markdown]
# ### Remove row

# %%
dictx = {'A' : [1 ,1, 3, 4, 5], 'B': ['a', 'a', 'c', 'd', 'e'], 'NUM': [0, 0, 0, 0, 0 ]}
dfx = pd.DataFrame(dictx)
dfx
# Out:
#    A  B  NUM
# 0  1  a    0
# 1  1  a    0
# 2  3  c    0
# 3  4  d    0
# 4  5  e    0

# %% [markdown]
# #### Drop row by index number

# %%
dfx.drop(1) # drops the second record but does not modify current dataframe
# Out:
#    A  B  NUM
# 0  1  a    0
# 2  3  c    0
# 3  4  d    0
# 4  5  e    0

# %%
dfx
# Out:
#    A  B  NUM
# 0  1  a    0
# 1  1  a    0
# 2  3  c    0
# 3  4  d    0
# 4  5  e    0

# %%
dfx.drop([1,2]) # drop multiple rows
# Out:
#    A  B  NUM
# 0  1  a    0
# 3  4  d    0
# 4  5  e    0

# %% [markdown]
# #### Drop by condition

# %%
 dfx.drop(dfx[dfx.A <= 3].index)
# Out:
#    A  B  NUM
# 3  4  d    0
# 4  5  e    0
