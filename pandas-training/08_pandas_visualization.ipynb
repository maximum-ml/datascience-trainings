# %% [markdown]
# ## Pandas - Plotting

# %%
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv('data/df1', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %% [markdown]
# ### Histogram of the data from a single column

# %% [markdown]
# It is calling matplotlib under the hood

# %%
df1['A'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns # this will make the charts to look in seaborn style (seems in jupyter lab it's a default setting)

# %%
df1['A'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
# A different way to create a histogram
df1['A'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['A'].plot.hist() # yet another way to print hist
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.index.name = 'IDX'
df1.head()
#df1.plot.line(x='IDX', y='B', figsize=(10,4)) TODO
# Out:
#                    A         B         C         D
# IDX
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.scatter(x='A', y='B', figsize=(8,8))
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap='coolwarm', figsize=(10,8)) # c - color
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2 = pd.read_csv('data/df2')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       10 non-null     float64
#  1   b       10 non-null     float64
#  2   c       10 non-null     float64
#  3   d       10 non-null     float64
# dtypes: float64(4)
# memory usage: 448.0 bytes

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df2.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df2.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df2.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:>

# %%
df2.hist() # for the whole table will produce hist for each column
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>,
#         <AxesSubplot:title={'center':'d'}>]], dtype=object)

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df0 = pd.DataFrame(np.random.randn(1000,2), columns=['a', 'b'])
df0.head()
# Out:
#           a         b
# 0 -1.657337 -1.305189
# 1  0.468217  1.671964
# 2 -1.657440  1.054201
# 3  0.270204  1.459649
# 4 -1.368037  0.010739

# %%
df0.plot.hexbin(x='a', y='b', gridsize=15, figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2['a']
# Out:
# 0    0.039762
# 1    0.937288
# 2    0.780504
# 3    0.672717
# 4    0.053829
# 5    0.286043
# 6    0.430436
# 7    0.312296
# 8    0.187765
# 9    0.908162
# Name: a, dtype: float64

# %%
df2['a'].plot.kde() # kernel desity estimation or (df2['a'].plot.density() ) # przybliża funkcję gęstości na podstawie próbek rozkładu
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df_x = pd.DataFrame(np.random.randn(50, 3), columns=['a', 'b', 'c'])

# %%
df_x.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
